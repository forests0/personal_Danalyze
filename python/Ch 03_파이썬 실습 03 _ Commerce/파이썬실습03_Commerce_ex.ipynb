# %% [markdown]
# #Data 03: Online retail data
# Online retail 데이터는 영국에 있는 온라인 소매점의 2010 년 1 월 12 일부터 2011 년 9 월 12 일 사이에 발생한 모든 주문 내역입니다.
#
# * data from: https://archive.ics.uci.edu/ml/datasets/online+retail#

# %% [markdown]
# ##1.데이터 둘러보기

# %%
#한글 폰트 설정하기
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
#런타임 다시 시작

# %%
#기본 패키지 불러오기
import math
import _____ as np
import _______ as pd
import _______ as sns
import _________.______ as plt

plt.style.use('______')
sns.set(font_scale=1)
plt.rc('font', family='NanumBarunGothic') 
plt.rcParams['font.family'] = 'NanumGothic'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#구글 드라이브 마운트하기(이미 되어있다면 건너뛴다)
from google.colab import drive 
drive.mount('/content/drive')

# %%
#데이터 불러오기
#드라이브에 올려준 엑셀 데이터 파일 불러오기(~43s)
oln = pd.read_excel('')

# %%
#불러온 데이터 일단 보기
oln.____(5)

# %% [markdown]
# <컬럼 설명>
#
#
# * InvoiceNo: 주문번호
# * StockCode: 상품코드
# * Description: 상품 설명
# * Quantity: 수량
# * InvoceDate: 주문날짜
# * UnitPrice: 개별 가격
# * CustomerID: 고객번호
# * Country: 국가

# %% [markdown]
# * 범주형 변수: *빈도frequency 계산 가능*
#                invoiceno, stockcode, description, customerid, country
# * 연속형 변수: *평균, 표준편차, min/max 등 수치 계산 가능*
#                quantity, invoicedate(시간변수), unitprice

# %%
#데이터 기본 정보 확인하기
oln.____()

# %%
#연속형(수치) 데이터의 통계치 확인하기
oln.________()

# %%
#범주형 데이터의 통계치 확인하기
oln.describe(include=np.______)

# %%
#데이터 내용 정리해서 출력하기
print("총 데이터 수: ", oln._____[0]*oln._____[1])
print("총 결측치 수: {} = 전체 데이터의 {:.2f}% ".format(oln.isnull().sum().sum(), (oln.isnull().sum().sum()*100)/(oln._____[0]*oln._____[1])))
print("전체 국가 수: ", oln.Country._________())
print("전체 판매 물건 수: ", oln.Description._________())

# %% [markdown]
# ##2.질문하기
#
#
# * 어떤 고객이 가장 지출을 많이 했을까?
# * 상품 금액의 분포는?
# * 어떤 물건의 주문량이 높을까?
# * 날짜에 따라 판매 금액을 확인해보자
# * 요일에 따라서 주문량이 다를까?
# * 국가 별 평균 구매 금액은?
# * 이 쇼핑몰 판매 물품의 주요 키워드는?

# %% [markdown]
# ##3.데이터 정비하기

# %% [markdown]
# ###3-1. 컬럼명 바꾸기

# %%
#컬럼명 앞이 대문자라서 일할때 불편하다
#컬럼명을 전부 소문자로 바꿔주자
oln.columns = oln.________.___._____()
oln.columns

# %% [markdown]
# ###3-2. 결측치 처리하기

# %%
#각 컬럼에 null 이 몇개 존재하는지 확인하기
oln.______().sum(axis=_)

# %%
# 결측치가 있는 컬럼 내용 확인하기
oln[oln.______().any(axis=_)].head()

# %%
#고객ID가 존재하지 않는 경우는 분석에 넣기 어려우므로, 결측치를 다 제거하고 분석하자
oln1 = oln.______()
oln1.info()

# %% [markdown]
# ###3-3.컬럼타입 변경하기

# %%
# 고객 id를 float64 > int64로 바꿔준다
oln1['customerid'] = oln1['customerid']._______('_____')
oln1.head()

# %% [markdown]
# ###3-4. 새로운 컬럼 만들기

# %%
#min, max 확인하면 판매수량 컬럼에 음수 값이 들어가 있음
print(___(oln1['quantity']), ___(oln1['quantity']))

# %%
#판매수량이 음수인 것 = 주문 취소?
#여기서는 판매수량이 양수인 것만 고려하자 
oln1 = oln1[oln1.quantity _ 0]

# %%
#가격 * 판매수량 = 사용 금액을 계산할 수 있다
#사용 금액(spent)라는 새 컬럼을 만들자!
oln1['spent'] = oln1['__________'] * oln1['__________']
oln1.head()

# %%
#월별 상품 수량 주문 집계를 하고 싶으므로 연,월,일 컬럼을 만든다
oln1['year'] = oln1['invoicedate'].dt.____      # 연(숫자)
oln1['month'] = oln1['invoicedate'].dt._____    # 월(숫자)
oln1['day'] = oln1['invoicedate'].dt.___        # 일(숫자)
oln1['weekday'] = oln1['invoicedate'].dt._______# 요일숫자
oln1['hour'] = oln1['invoicedate'].dt.____      # 시(숫자)
oln1.head()

# %% [markdown]
# ##4.EDA & Visualization

# %% [markdown]
# ###4-1.간단한 분석

# %%
#주문 순위 Top 10인 상품
oln1.description.____________().head(__)

# %%
#주문량이 많은 상위 5개 국가를 bar plot으로 나타내기
oln1.country.___________().head(_).plot.___()

# %%
#가장 돈을 많이 쓴 고객과 가장 적게 쓴 고객은?
#고객id에 대해 사용금액(spent)컬럼을 더해서 집계하기
res1 = oln1[['customerid','spent']]._______(['____________']).sum()
res1.sort_values('spent', ___________=False)

res1 = res1[(res1['spent'] _ 0)] #구매 금액이 0 이상인 고객만 산출하기

print('고객번호 {} 이 가장 소비를 많이 했다 {:.2f}'.format(int(res1['spent'].______()), res1['spent'].max()))
print('고객번호 {} 이 가장 소비를 적게 했다 {:.2f}'.format(int(res1['spent'].______()), res1['spent'].min()))

# %%
#상품 금액대의 분포를 box plot으로 그려보자

f, ax = plt.subplots(1, 1, figsize=(5, 6), dpi = 80)

#box plot
#최댓값, 최솟값, 중앙값을 사용하여 자료의 측정값들이 어떤 모양으로 분포되어 있는지 등을 쉽게 알 수 있다
sns._______(oln1['unitprice'], showfliers = False, ax=__)

#대체로 2 파운드 근처에서 상품 가격대가 형성되어 있다

# %%
#주문량이 많은 상품 금액대 파악1
chk1 = oln1[oln1['unitprice']<=8]._____[_]/oln1['unitprice'].shape[0]*100
print("8 파운드 이하 상품 주문이 {:.2f} % 를 차지합니다.".format(chk1))

# %%
#주문량이 많은 상품 금액대 파악2
chk2 = np.___(oln1[oln1['unitprice']<=8]._____)/np.___(oln1._____)*100
print("수익의 {:.2f} % 는 8 파운드 이하의 상품에서 발생합니다.".format(chk2))

# %% [markdown]
# ###4-2. 날짜에 따른 판매금액(시계열)

# %%
#주문 날짜에 따른 판매금액(spent)을 나타내자
oln1.____(x = '____________', y = '_____', color='orange', figsize=(15, 6))

plt._____("주문날짜 별 판매금액 추이", fontsize = 15)
plt.______('날짜')
plt.______('판매금액')

plt.show()
#실제 판매자라면? 판매금액이 높은 날 어떤 일이 있었는지 등을 분석할 수 있다

# %% [markdown]
# ###4-3. 요일별/시간별 주문량

# %%
#주문번호가 중복되므로(하나의 주문번호당 상품 여러개) 요일 별 주문번호 하나만 남기기
res2 = oln1.______________(['invoiceno'], keep='first')
res2

# %%
#요일 별 주문량 확인하기(주문번호 기준)
g1 = res2[['weekday','invoiceno']].________('_______').____().plot(kind='___', figsize=(13,6))

g1.set_xlabel('요일',fontsize=15)
g1.set_ylabel('주문량(주문번호 기준)',fontsize=15)
g1.set_title('요일 별 주문량',fontsize=17)
g1.set_xticklabels(('Mon','Tue','Wed','Thur','Fri','Sun'), rotation='horizontal', fontsize=15)
g1.legend('') #legend가 없어도 되는 그래프에서는 삭제해줘도 무방

plt.show()

# %%
#시간대별 주문번호 수 count 하기
res3 = res2[['hour','invoiceno']].________('____')._____()
res3

# %%
#시간대 별 주문량 확인하기(주문번호 기준)
g2 = res3.____(____='bar', _____ = 'orange', figsize=(13,6))

g2.set_xlabel('시간',fontsize=13)
g2.set_ylabel('주문량(주문번호 기준)',fontsize=13)
g2.set_title('시간대별 주문량',fontsize=16)
g2.legend('')

plt.show()

# %% [markdown]
# ###4-4. 국가별 1회 주문의 평균 구매금액

# %%
#국가 별 주문 당 평균 구매금액
#국가별 주문 건수를 센 다음, (전체 쓴 돈 / 주문건수) 구하자!
#필요한 컬럼만 가져오기
res4 = oln1[['_________','_____','_______','__________']]
res4

# %%
#국가별 주문번호를 집계하고 count = 1 컬럼을 단다
aa = res4.groupby(['_______', '___________']).sum()
aa['count'] = _
aa

# %%
#aa를 국가별로 sum 하면 count.sum() = 국가별 주문건수
bb = aa.______('country').___()
bb

# %%
#bb의 spent/count 하면 해당 국가별 주문건당 평균 매출액을 집계할 수 있다
bb['avg_spent'] = bb['______'] / bb['_____']
bb.___________(['count','avg_spent'], ascending=False, inplace=True)
bb.head()

# %%
#국가별 평균 구매금액 그래프 그리기
color = plt.cm.viridis(np._______(0, 1, 38))

#가로로 그릴 때는 barh 옵션 사용
bb['avg_spent'].________________().plot(kind='____',figsize=(12,9),color=_____)
plt.title('국가별 주문 1건 당 평균 매출액', size=18)
plt.xlabel('금액',size=15)

# %% [markdown]
# ###4-5.상품명에서 가장 빈번하게 등장하는 단어

# %%
#Word cloud 패키지 import
from wordcloud import _________
from wordcloud import _________

# %%
#World cloud를 손쉽게 그릴 수 있다!
stopwords = set(STOPWORDS)
stopwords.___('______') #제외할 단어에 dtype 추가

wordcloud = __________(stopwords=________, background_color='black', width=800, height=600, colormap = 'PuBu').generate(str(oln1['__________']))

plt.axis('off')
plt.title('주문 목록에서 자주 등장하는 단어', fontsize = 18)
plt.imshow(wordcloud)
#plt.show()

# %% [markdown]
# ##5.Review

# %% [markdown]
# * Online Retail 데이터는:
# 총 데이터 수:  4335272
# 총 결측치 수: 136534 = 전체 데이터의 3.15%
# 전체 국가 수:  38
# 전체 판매 물건 수:  4223
#
# * 어떤 고객이 가장 지출을 많이 했을까?
#   : 고객번호 1689 이 가장 소비를 많이 했다
#   : 고객번호 3217 이 가장 소비를 적게 했다
#
# * 상품 금액의 분포는?
#   : 대체로 2 파운드 근처에서 상품 가격대가 형성되어 있다
#   : 8 파운드 이하 상품 주문이 93.28 % 를 차지한다
#   : 수익의 88.09 % 는 8 파운드 이하의 상품에서 발생한다
# * 어떤 물건의 주문량이 높을까?
#   : WHITE HANGING HEART T-LIGHT HOLDER
# * 주문 날짜 별 판매량은?
# * 요일/시간에 따라서 주문량이 다를까?
#   : 목요일 주문이 가장 많고 일요일이 주문이 가장 적다
#   : 낮 12시에 주문이 가장 많다
# * 국가별 고객 1인당 평균 구매 금액은?
#   : 영국의 매출액이 가장 높지만, 1인당 구매금액은 싱가포르가 가장 높다
# * 이 쇼핑몰 판매 물품의 주요 키워드는?
#   : white, heart, children
